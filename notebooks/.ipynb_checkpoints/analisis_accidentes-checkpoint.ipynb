# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Verificacion de librerias")
# Out:
# Verificacion de librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.__version__
# Out:
# '3.0.5'

# %%
print("Proyecto: Análisis de Accidentes de Tránsito en Chile")
# Out:
# Proyecto: Análisis de Accidentes de Tránsito en Chile

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\marti\OneDrive\Escritorio\Repo\data\acc.csv")

df.head()
# Out:
#     Año Tipo de Vehículo  Siniestros  Fallecidos  Graves  Menos graves  Leves
# 0  2002        Automóvil       24511         266    1654          1900  11385
# 1  2002        Bicicleta        4192         175     800           670   2425
# 2  2002    Bus / Taxibus        8614          60     599           770   4660
# 3  2002           Camión        3473          73     304           219    881
# 4  2002        Camioneta        8125         130     735           735   3365

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               293 non-null    int64
#  1   Tipo de Vehículo  293 non-null    str
#  2   Siniestros        293 non-null    int64
#  3   Fallecidos        293 non-null    int64
#  4   Graves            293 non-null    int64
#  5   Menos graves      293 non-null    int64
#  6   Leves             293 non-null    int64
# dtypes: int64(6), str(1)
# memory usage: 16.2 KB

# %%
df.columns
# Out:
# Index(['Año', 'Tipo de Vehículo', 'Siniestros', 'Fallecidos', 'Graves',
#        'Menos graves', 'Leves'],
#       dtype='str')

# %%
siniestros_por_vehiculo = (
df.groupby("Tipo de Vehículo")["Siniestros"]
.sum()
.sort_values(ascending=False)
)

# %%
siniestros_por_vehiculo
# Out:
# Tipo de Vehículo
# Automóvil                     1107574
# Camioneta                      339438
# Peatón                         202645
# Bus / Taxibus                  166301
# Camión                         128003
# Motocicleta                    119821
# Furgón                          96484
# Bicicleta                       90142
# Jeep                            75799
# Otros                           34483
# Minibus                         25988
# Dado a la fuga                  16721
# Patín motorizado (Scooter)        353
# Se ignora                         208
# Triciclo                          138
# Name: Siniestros, dtype: int64

# %%
import matplotlib.pyplot as plt

siniestros_por_vehiculo.plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Siniestros por tipo de vehículo")
plt.xlabel("Tipo de vehículo")
plt.ylabel("Cantidad de siniestros")

plt.show()

# %%
siniestros_por_año = (
    df.groupby("Año")["Siniestros"]
    .sum()
)

siniestros_por_año
# Out:
# Año
# 2002     64101
# 2003     67787
# 2004     71077
# 2005     70234
# 2006     67413
# 2007     80302
# 2008     84759
# 2009     83149
# 2010     85332
# 2011     91800
# 2012     90535
# 2013    107718
# 2014    114398
# 2015    116674
# 2016    133627
# 2017    137762
# 2018    130035
# 2019    130713
# 2020     93503
# 2021    116818
# 2022    125927
# 2023    114872
# 2024    112650
# 2025    112912
# Name: Siniestros, dtype: int64

# %%
siniestros_por_año.plot(
    kind="line",
    marker="o",
    figsize=(10,5)
)

plt.title("Evolución de siniestros por año")
plt.xlabel("Año")
plt.ylabel("Cantidad de siniestros")

plt.grid(True)

plt.show()

# %%
fallecidos_por_vehiculo = (
    df.groupby("Tipo de Vehículo")["Fallecidos"]
    .sum()
    .sort_values(ascending=False)
)

fallecidos_por_vehiculo.plot(
    kind="bar",
    figsize=(10,5),
    color="red"
)

plt.title("Fallecidos por tipo de vehículo")
plt.xlabel("Tipo de vehículo")
plt.ylabel("Fallecidos")

plt.show()
